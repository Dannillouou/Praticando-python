# %%
# Exemplo 6

import pandas as pd

from bokeh.io import output_file, show
from bokeh.plotting import figure
from bokeh.sampledata.periodic_table import elements
from bokeh.models import ColumnDataSource

# %%
# setando configuração do pandas para mostrar todas as colunas do dataset quando pedirmos
pd.set_option("display.max_columns", None)
print(elements.head())
print(elements.count())
print(elements)
# Out:
#    atomic number symbol       name atomic mass      CPK  \
# 0              1      H   Hydrogen     1.00794  #FFFFFF
# 1              2     He     Helium    4.002602  #D9FFFF
# 2              3     Li    Lithium       6.941  #CC80FF
# 3              4     Be  Beryllium    9.012182  #C2FF00
# 4              5      B      Boron      10.811  #FFB5B5
#
#   electronic configuration  electronegativity  atomic radius ion radius  \
# 0                      1s1               2.20           37.0        NaN
# 1                      1s2                NaN           32.0        NaN
# 2                 [He] 2s1               0.98          134.0    76 (+1)
# 3                 [He] 2s2               1.57           90.0    45 (+2)
# 4             [He] 2s2 2p1               2.04           82.0    27 (+3)
#
#    van der Waals radius    IE-1    EA standard state      bonding type  \
# 0                 120.0  1312.0 -73.0            gas          diatomic
# ...

# %%
# retirando elementos na
elements.dropna(inplace=True)

# print(elements.head())
# print(elements.count())
# print(elements)
# sobraram 31 elementos
# Out:
#    atomic number symbol      name atomic mass      CPK  \
# 2              3     Li   Lithium       6.941  #CC80FF
# 5              6      C    Carbon     12.0107  #909090
# 6              7      N  Nitrogen     14.0067  #3050F8
# 7              8      O    Oxygen     15.9994  #FF0D0D
# 8              9      F  Fluorine  18.9984032  #90E050
#
#   electronic configuration  electronegativity  atomic radius ion radius  \
# 2                 [He] 2s1               0.98          134.0    76 (+1)
# 5             [He] 2s2 2p2               2.55           77.0    16 (+4)
# 6             [He] 2s2 2p3               3.04           75.0   146 (-3)
# 7             [He] 2s2 2p4               3.44           73.0   140 (-2)
# 8             [He] 2s2 2p5               3.98           71.0   133 (-1)
#
#    van der Waals radius    IE-1     EA standard state      bonding type  \
# 2                 182.0   520.0  -60.0          solid          metallic
# ...

# %%
color_dict = {"gas" : "green", "liquid" : "blue", "solid" : "grey"}

# lista para criar a coluna de cores no dataset
colors = []

# fazendo correspondencia de cor com estado padrão do elemento
for each_element in elements["standard state"]:
    colors.append(color_dict[each_element])
    
# adicionando coluna com as cores
elements["colors"] = colors

# criando nova coluna com ajuste do raio de van der Waals
elements["size"] = elements["van der Waals radius"] / 10

print(elements.head())
# Out:
#    atomic number symbol      name atomic mass      CPK  \
# 2              3     Li   Lithium       6.941  #CC80FF
# 5              6      C    Carbon     12.0107  #909090
# 6              7      N  Nitrogen     14.0067  #3050F8
# 7              8      O    Oxygen     15.9994  #FF0D0D
# 8              9      F  Fluorine  18.9984032  #90E050
#
#   electronic configuration  electronegativity  atomic radius ion radius  \
# 2                 [He] 2s1               0.98          134.0    76 (+1)
# 5             [He] 2s2 2p2               2.55           77.0    16 (+4)
# 6             [He] 2s2 2p3               3.04           75.0   146 (-3)
# 7             [He] 2s2 2p4               3.44           73.0   140 (-2)
# 8             [He] 2s2 2p5               3.98           71.0   133 (-1)
#
#    van der Waals radius    IE-1     EA standard state      bonding type  \
# 2                 182.0   520.0  -60.0          solid          metallic
# ...
